# %%
import pandas as pd
import requests
import os
import time

def area_list(Area, headers):
    area_json = 'https://static.104.com.tw/category-tool/json/Area.json'
    response = requests.get(url=area_json, headers=headers)
    df_area = pd.DataFrame(response.json()[0]['n'])
    df_area = df_area.explode('n', ignore_index=True)
    df_area['des2'] = df_area['n'].apply(lambda x: x['des'])
    df_area['no2'] = df_area['n'].apply(lambda x: x['no'])
    df_area = df_area.loc[:, ['des', 'no', 'des2', 'no2']]
    Area_list = list()
    for area in Area:
        for index in df_area.index:
            if df_area.iloc[index]['des']  == area:
                areacode = df_area.iloc[index]['no']
            elif df_area.iloc[index]['des2']  == area:
                areacode = df_area.iloc[index]['no2']
        Area_list.append(areacode)
    return Area_list


start_time = time.time()
search_list = {
    'jobName': '職務名稱',
    'custName': '公司名稱',
    'jobAddrNoDesc': '工作地點',
    'jobAddress': '詳細地址',
    'optionEdu': '學歷',
    'periodDesc': '工作經歷',
    'salaryDesc': '待遇',
    'applyDesc': '應徵人數',
    'description': '工作內容',
    'coIndustryDesc': '產業描述',
    'appearDate': '發布日期',
    'link': '網頁連結'
}
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36',
    'Referer': 'https://www.104.com.tw/jobs/main/'
}
folder_path = './104'
max_page = 10        # 使用者可自行輸入
ro = '1'  # 0: 全部, 1: 全職, 2: 兼職
isnew = '7'  # 幾日內更新的工作
keyword = '軟體工程師'
Area = ['台北市中正區', '新北市']  # 想搜尋的地區
Area = area_list(Area, headers)
df = list()
for area in Area:
    for page in range(1, max_page):
        url = f'https://www.104.com.tw/jobs/search/list?ro={ro}&isnew={isnew}&kwop=7&keyword={keyword}&area={area}&order=15&asc=0&page={page}&mode=l'
        response = requests.get(url=url, headers=headers)
        ndf = pd.DataFrame(response.json()['data']['list'])
        df.append(ndf)
        if ndf.shape[0] < 30:
            break
df = pd.concat(df, ignore_index=True)
df = df.rename(columns=search_list)  # 可寫成字典更改column名或index名
if not os.path.exists(folder_path):
    os.mkdir(folder_path)
df.to_csv(os.path.join(folder_path, f'{keyword}.csv'), index=0, encoding='utf-8-sig')
end_time = time.time()
print('運算時間:\t', end_time - start_time)
df
# Out:
# 運算時間:	 31.748793601989746
#     jobType     jobNo                                       職務名稱  \
# 0         1   8299084                       CRD 手機遊戲工程師【歡迎應屆畢業生】
# 1         1  11867437                      RD 網頁/PHP工程師【歡迎應屆畢業生】
# 2         1  13034928                                    C程式設計人員
# 3         1  13034934                                   C#程式設計人員
# 4         0  12376125   軟體工程師 Software Engineer- Embedded System
# ..      ...       ...                                        ...
# 543       0  13051700                                  智慧能源前端工程師
# 544       0  12911536  【S】Linux / Yocto / OpenWRT BSP 軟體工程師 (土城)
# 545       2  12908531                        資深.NET 軟體開發工程師 (新店)
# 546       0   7941327                          自動控制軟體工程師(C# C++)
# 547       0  12427529                                 APP軟體研發工程師
#
#                                         jobNameSnippet jobRole jobRo  \
# 0                                 CRD 手機遊戲工程師【歡迎應屆畢業生】       1     1
# 1                                RD 網頁/PHP工程師【歡迎應屆畢業生】       1     1
# 2                                              C程式設計人員       1     1
# 3                                             C#程式設計人員       1     1
# 4    <em class='b-txt--highlight'>軟體工程師</em> <em cl...       1     1
# ..                                                 ...     ...   ...
# 543        智慧能源前端<em class='b-txt--highlight'>工程師</em>       1     1
# 544  【S】Linux / Yocto / OpenWRT BSP <em class='b-tx...       1     1
# 545  資深.NET <em class='b-txt--highlight'>軟體開發工程師</e...       1     1
# 546  自動控制<em class='b-txt--highlight'>軟體工程師</em>(C#...       1     1
# 547  APP<em class='b-txt--highlight'>軟體</em>研發<em c...       1     1
#
#       jobAddrNo    工作地點              詳細地址  \
# 0    6001001001  台北市中正區     羅斯福路二段100號10樓
# 1    6001001001  台北市中正區     羅斯福路二段100號10樓
# 2    6001001001  台北市中正區           或新北市板橋區
# 3    6001001001  台北市中正區           或新北市板橋區
# 4    6001001001  台北市中正區  杭州南路一段15-1號10樓之一
# ..          ...     ...               ...
# 543  6001002025  新北市五股區
# 544  6001002016  新北市土城區             民生街4號
# 545  6001002011  新北市新店區         復興路43號10樓
# 546  6001002018  新北市樹林區           八德路432號
# 547  6001002020  新北市三重區    重新路五段609巷6號10樓
#
#                                                   工作內容  ...              tags  \
# 0    1. 使用Cocos開發遊戲(無經驗可)\n2. 使用JavaScript語言\n3. 維護...  ...          [員工200人]
# 1    開發web/手機遊戲\n－ 遊戲功能開發\n－ 活動開發及官網維護\n－ 資料庫操作及數據處...  ...          [員工200人]
# 2    ※必備資格條件：\r\n教育部認可之大學(含)以上資訊相關系所畢業。\r\n※具下列資格條件...  ...          [員工290人]
# 3    ※必備資格條件：\r\n教育部認可之大學(含)以上資訊相關系所畢業。\r\n※具下列資格條件...  ...          [員工290人]
# 4    【Job Description】  \n1. Develop Low latency Tr...  ...           [員工60人]
# ..                                                 ...  ...               ...
# 543  職務類別：[[[軟體設計工程師]]]、Internet程式設計師、通訊[[[軟體工程師]]]...  ...  [上市上櫃, 員工11000人]
# 544  1. OpenWRT/ Yocto BSP 開發環境、功能整合\n2. OpenWRT/ L...  ...                []
# 545  1.依產品及專案需求，進行 ASP.NET MVC 應用程式開發。\n2.依產品及專案需求，...  ...           [員工40人]
# 546  1.參與應用[[[軟體]]]之規劃與設計\n2.參與自動化機台[[[軟體]]]架構與系統設計...  ...           [員工45人]
# 547  Java等程式語言為佳\n4.熟VOIP架構為佳\n\n\n【必要條件】\n1.負責專案[[...  ...          [員工130人]
#
#          landmark                                               網頁連結  \
# 0      距捷運古亭站50公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 1      距捷運古亭站50公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 2                  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 3                  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 4    距捷運善導寺站410公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# ..            ...                                                ...
# 543                {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 544                {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 545                {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 546                {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 547  距捷運先嗇宮站410公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
#
#               jobsource                                 jobNameRaw  \
# 0            hotjob_chr                       CRD 手機遊戲工程師【歡迎應屆畢業生】
# 1            hotjob_chr                      RD 網頁/PHP工程師【歡迎應屆畢業生】
# 2            hotjob_chr                                    C程式設計人員
# 3            hotjob_chr                                   C#程式設計人員
# 4    jolist_a_relevance   軟體工程師 Software Engineer- Embedded System
# ..                  ...                                        ...
# 543  jolist_d_relevance                                  智慧能源前端工程師
# 544  jolist_d_relevance  【S】Linux / Yocto / OpenWRT BSP 軟體工程師 (土城)
# 545  jolist_d_relevance                        資深.NET 軟體開發工程師 (新店)
# 546  jolist_d_relevance                          自動控制軟體工程師(C# C++)
# 547  jolist_d_relevance                                 APP軟體研發工程師
#
#            custNameRaw          lon         lat remoteWorkType  \
# 0           慧邦科技股份有限公司  121.5223326  25.0267506              0
# 1           慧邦科技股份有限公司  121.5223326  25.0267506              0
# 2     財團法人中華民國證券櫃檯買賣中心  121.5198716  25.0421407              0
# 3     財團法人中華民國證券櫃檯買賣中心  121.5198716  25.0421407              0
# 4             威旭資訊有限公司  121.5267675  25.0427628              0
# ..                 ...          ...         ...            ...
# 543    台塑_臺灣塑膠工業股份有限公司  121.4386586  25.0848317              0
# 544  富智康國際股份有限公司(鴻海集團)  121.4143447  24.9613226              0
# 545         睿傳數據股份有限公司  121.5369557  24.9866876              0
# 546         翔慶精密工業有限公司  121.4017587  24.9704558              0
# 547         通航國際股份有限公司  121.4675924  25.0450856              0
#
#                                major
# 0    [資訊工程相關, 數學及電算機科學學科類, 電機電子工程相關]
# 1     [資訊工程相關, 資訊管理相關, 其他數學及電算機科學相關]
# 2                           [資訊管理相關]
# 3                           [資訊管理相關]
# 4                 [電機電子工程相關, 資訊工程相關]
# ..                               ...
# 543                       [電機電子工程相關]
# 544       [資訊工程相關, 資訊管理相關, 電機電子工程相關]
# 545                         [資訊工程相關]
# 546             [數學及電算機科學學科類, 工程學科類]
# 547                               []
#
# [548 rows x 40 columns]

# %%
import pandas as pd
import requests
def area_list(Area, headers):
    area_json = 'https://static.104.com.tw/category-tool/json/Area.json'
    response = requests.get(url=area_json, headers=headers)
    df_area = pd.DataFrame(response.json()[0]['n'])
    df_area = df_area.explode('n', ignore_index=True)
    df_area['des2'] = df_area['n'].apply(lambda x: x['des'])
    df_area['no2'] = df_area['n'].apply(lambda x: x['no'])
    df_area = df_area.loc[:, ['des', 'no', 'des2', 'no2']]
    Area_list = list()
    for area in Area:
        for index in df_area.index:
            if df_area.iloc[index]['des']  == area:
                areacode = df_area.iloc[index]['no']
            elif df_area.iloc[index]['des2']  == area:
                areacode = df_area.iloc[index]['no2']
        Area_list.append(areacode)
    return Area_list

# %%
import requests
area_json = 'https://static.104.com.tw/category-tool/json/Area.json'
ro = '1'  # 0: 全部, 1: 全職, 2: 兼職
isnew = '7'  # 幾日內更新的工作
keyword = '軟體工程師'
area = '6001001001'  # 台北市
url = f'https://www.104.com.tw/jobs/search/list?ro={ro}&isnew={isnew}&kwop=7&keyword={keyword}&area={area}&order=15&asc=0&page=2&mode=l'
response = requests.get(url=url, headers=headers)
response.json()
# Out:
# {'status': 200,
#  'action': [],
#  'data': {'query': {'ro': 1,
#    'jobcat': '',
#    'isnew': 7,
#    'kwop': 7,
#    'keyword': '軟體工程師',
#    'expansionType': 'area,spec,com,job,wf,wktm',
#    'excludeKeyword': '',
#    'area': '6001001001',
#    'indcat': '',
#    'expcate': '',
#    'edu': '',
#    'order': 15,
#    'asc': 0,
#    'zone': '',
#    'dep': '',
#    'dis_role': '',
#    'lang': '',
#    'sr': '',
#    'sctp': '',
#    'scmin': '',
#    'scmax': '',
#    'scstrict': '',
#    'scneg': '',
#    'excludeJobKeyword': '',
#    'excludeCompanyKeyword': '',
#    'excludeCompanyByCustno': '',
#    'excludeIndustryCat': '',
#    's9': '',
#    's5': '',
#    'wktm': '',
#    'startby': '',
#    'rostatus': '',
#    'page': 2,
#    'wf': '',
#    'jobexp': '',
#    'wt': '',
#    'mode': 'l',
#    'jobsource': '',
#    'utm_source': '',
#    'utm_medium': '',
#    'utm_campaign': '',
#    'c': '',
#    'custNo': '',
#    'jobNo': '',
#    'dist': '',
#    'lat': '',
#    'lon': '',
#    'mrt': '',
#    'indArea': '',
#    'newZone': '',
#    'searchTempExclude': '',
#    'manage': '',
#    'showLatLon': '',
#    'showDutyTime': '',
#    'langFlag': 0,
#    'langStatus': 0,
#    'recommendJob': 1,
#    'hotJob': 1,
#    'remoteWork': ''},
#   'filterDesc': {'jobcat': [],
#    'indcat': [],
#    'area': [{'no': '6001001001', 'des': '台北市中正區'}],
#    'dep': [],
#    'mrt': [],
#    'excludeIndustryCat': [],
#    'excludeCompanyByCustno': [],
#    'recommendIndcat': [{'no': '1001000000', 'des': '電子資訊／軟體／半導體相關業'},
#     {'no': '1002000000', 'des': '一般製造業'},
#     {'no': '1003000000', 'des': '批發／零售／傳直銷業'},
#     {'no': '1001001000', 'des': '軟體及網路相關業'},
#     {'no': '1007000000', 'des': '旅遊／休閒／運動業'}],
#    'indArea': [],
#    'recommendMrt': [{'no': '99001001016', 'des': '西湖站'},
#     {'no': '99001005018', 'des': '市政府站'},
#     {'no': '99001005019', 'des': '永春站'},
#     {'no': '99001003017', 'des': '南京復興站'},
#     {'no': '99001004008', 'des': '松江南京站'},
#     {'no': '99001003019', 'des': '南京三民站'}]},
#   'queryDesc': {'ro': '全職',
#    'isnew': '一週內',
#    'keyword': '軟體工程師',
#    'area': '台北市中正區'},
#   'list': [{'jobType': '0',
#     'jobNo': '10642827',
#     'jobName': 'AI工程師',
#     'jobNameSnippet': "AI<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '忠孝東路1段9號6樓',
#     'description': '項目］\r\n1.熟 linux系統\r\n2.app 開發經驗\r\n3.懂簡單的網頁開發\r\n\r\n［特質］\r\n1.能獨立思考並具良好的溝通協調能力\r\n2.對[[[軟體]]]新技能開發有熱誠  \r\n \r\n',
#     'optionEdu': '專科',
#     'period': '02',
#     'periodDesc': '1年',
#     'applyCnt': '00001',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000051405',
#     'custName': '旺捷智能感知股份有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0035000',
#     'salaryHigh': '0050000',
#     'salaryDesc': '月薪35,000~50,000元',
#     's10': '50',
#     'appearDate': '20220923',
#     'appearDateDesc': '9/23',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "項目］\r\n1.熟 linux系統\r\n2.app 開發經驗\r\n3.懂簡單的網頁開發\r\n\r\n［特質］\r\n1.能獨立思考並具良好的溝通協調能力\r\n2.對<em class='b-txt--highlight'>軟體</em>新技能開發有熱誠  \r\n \r\n",
#     'tags': ['員工20人'],
#     'landmark': '距捷運善導寺站30公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6c423?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/6c423?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bj2z1?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'AI工程師',
#     'custNameRaw': '旺捷智能感知股份有限公司',
#     'lon': '121.52362337477719',
#     'lat': '25.045017634436014',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12349596',
#     'jobName': 'CRM/ERP軟體工程師',
#     'jobNameSnippet': "CRM/ERP<em class='b-txt--highlight'>軟體工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '杭州南路一段 26 號八樓',
#     'description': '表製作。\n - 系統及資料庫的規劃與設計。\n - 系統開發文件撰寫。\n - 與 PM 、[[[工程師]]]及使用者進行溝通及支援。\n\n\n',
#     'optionEdu': '大學',
#     'period': '03',
#     'periodDesc': '2年',
#     'applyCnt': '00001',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000109483',
#     'custName': '中華資安國際股份有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0045000',
#     'salaryHigh': '0080000',
#     'salaryDesc': '月薪45,000~80,000元',
#     's10': '50',
#     'appearDate': '20220921',
#     'appearDateDesc': '9/21',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "表製作。\n - 系統及資料庫的規劃與設計。\n - 系統開發文件撰寫。\n - 與 PM 、<em class='b-txt--highlight'>工程師</em>及使用者進行溝通及支援。\n\n\n",
#     'tags': [],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7cp0c?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7cp0c?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bkbsb?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'CRM/ERP軟體工程師',
#     'custNameRaw': '中華資安國際股份有限公司',
#     'lon': '121.5244119',
#     'lat': '25.0374492',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '13016770',
#     'jobName': 'Android手機APP工程師',
#     'jobNameSnippet': "Android手機APP<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '忠孝東路一段83號15樓之2',
#     'description': '訊串流、RESTFul API串接\n4. 定期做Code Review與同事討論自己今天寫的Code，技術分享。\n\n以及：\n1. 負責[[[軟體]]]之分析、設計以及程式撰寫。\n2. 規劃執行[[[軟體]]]架構及模組之設計，並控管[[[軟體]]]設計進度。\n3. 進行[[[軟體]]]之測試與修',
#     'optionEdu': '大學',
#     'period': '03',
#     'periodDesc': '2年',
#     'applyCnt': '00000',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000189823',
#     'custName': '智寶教育股份有限公司',
#     'coIndustry': '1005001009',
#     'coIndustryDesc': '其他教育服務業',
#     'salaryLow': '0045000',
#     'salaryHigh': '0075000',
#     'salaryDesc': '月薪45,000~75,000元',
#     's10': '50',
#     'appearDate': '20220923',
#     'appearDateDesc': '9/23',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "訊串流、RESTFul API串接\n4. 定期做Code Review與同事討論自己今天寫的Code，技術分享。\n\n以及：\n1. 負責<em class='b-txt--highlight'>軟體</em>之分析、設計以及程式撰寫。\n2. 規劃執行<em class='b-txt--highlight'>軟體</em>架構及模組之設計，並控管<em class='b-txt--highlight'>軟體</em>設計進度。\n3. 進行<em class='b-txt--highlight'>軟體</em>之測試與修",
#     'tags': ['員工11人'],
#     'landmark': '距捷運善導寺站310公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7qzsy?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7qzsy?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bm1rz?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'Android手機APP工程師',
#     'custNameRaw': '智寶教育股份有限公司',
#     'lon': '121.5263496',
#     'lat': '25.0443299',
#     'remoteWorkType': 0,
#     'major': ['資訊工程相關', '其他數學及電算機科學相關', '數理統計相關']},
#    {'jobType': '0',
#     'jobNo': '12892619',
#     'jobName': '  python工程師',
#     'jobNameSnippet': "  python<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': ' ',
#     'description': '1. 負責[[[軟體]]]之分析、設計以及程式撰寫。\r\n2. 規劃執行[[[軟體]]]架構及模組之設計，並控管[[[軟體]]]設計進度。\r\n3. 進行[[[軟體]]]之測試與修改。\r\n4. 規劃、執行與維護量產的產品。\r\n5. 協助研發[[[軟體]]]新技術與新工具。\r\n6. 管控[[[軟體]]]開發成本。\r\n7.',
#     'optionEdu': '專科',
#     'period': '00',
#     'periodDesc': '不拘',
#     'applyCnt': '00018',
#     'applyDesc': '11~30人應徵',
#     'custNo': '130000000193042',
#     'custName': '巴鈉德科技股份有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0000000',
#     'salaryHigh': '0000000',
#     'salaryDesc': '待遇面議',
#     's10': '10',
#     'appearDate': '20220919',
#     'appearDateDesc': '9/19',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "1. 負責<em class='b-txt--highlight'>軟體</em>之分析、設計以及程式撰寫。\r\n2. 規劃執行<em class='b-txt--highlight'>軟體</em>架構及模組之設計，並控管<em class='b-txt--highlight'>軟體</em>設計進度。\r\n3. 進行<em class='b-txt--highlight'>軟體</em>之測試與修改。\r\n4. 規劃、執行與維護量產的產品。\r\n5. 協助研發<em class='b-txt--highlight'>軟體</em>新技術與新工具。\r\n6. 管控<em class='b-txt--highlight'>軟體</em>開發成本。\r\n7.",
#     'tags': ['員工10人'],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7oc0b?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7oc0b?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bm49e?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '  python工程師',
#     'custNameRaw': '巴鈉德科技股份有限公司',
#     'lon': '121.5198716',
#     'lat': '25.0421407',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '10568254',
#     'jobName': '前端開發工程師（React JS）',
#     'jobNameSnippet': "前端開發<em class='b-txt--highlight'>工程師</em>（React JS）",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '北平東路30-1號4樓',
#     'description': 'Cubewise是一家全球化的諮詢公司，專注於基於TM1，説明各大知名集團實現智能化經營管理分析，優化管理流程。 Web developer崗位主要涉及開發TM1 web应用开发，也会涉及到front-end UI/Template/Dashboard模組。基於顧問團隊搭建好的模型，配合顧問團隊在前端方面更好的幫助客戶使用我們的分析系統。 我們與各行業龍頭企業合作，幫助他們解決問題的同時學習接觸到到更多各行業頂尖企業相關技能。\n\nJob Requirement\n\n1.至少3年以上的前端體驗扎實的開發經驗，对于前端架构有所了解 At least 3+ years front-end solid development experience, better if knows the front-end architecture.\n2.精通 React JS, jQuery, JavaScript , HTML, CSS\tProficiency in React JS, jQuery, JavaScript, HTML, CSS  JS \n3.有Bootstrap, UI-Bootstrap, D3 / nvD3, Charting, Sheet JS等方面的熟悉和實踐經驗 Familiar and hands-on experience on using Bootstrap, UI-Bootstrap, D3 / nvD3, Charting, Sheet\n4.使用 GitHub 或類似的原始程式碼管理工具的經驗, 熟悉前端網頁程式開發和部署週期管理  Experience on using GitHub or similar source control tool and familiar with front-end web development and deployment cycle management \n5.具有各種 web 服務 (Tomcat、Nginx等)、瀏覽器 (Chrome、火狐、Safari 等) 和移動平臺 (Android、iOS 等) 的經驗, 以及每個用戶端的性能和頁面優化  Experience with various web services (Tomcat, Nginx etc.), browsers (Chrome, Firefox, Safari, etc) and mobile platform (Android, iOS etc.), as well as performance and page optimization on each client \n6.能够通过单元测试实现高性能、可重用的组件。Able to implement high performing, reusable components with unit test.\n7.有Python（Flask）开发经验加分  Ideal candidates would also have experience in back-end web development like Python\n8.具有團隊合作精神, 能夠與泛亞洲和國際團隊一起工作 Self-motivated team player able to work well with pan Asian and international teams \n9.強烈的責任感和學習渴望 Strong sense of responsibility and eagerness to learn  \n',
#     'optionEdu': '專科',
#     'period': '03',
#     'periodDesc': '2年',
#     'applyCnt': '00007',
#     'applyDesc': '6~10人應徵',
#     'custNo': '130000000115323',
#     'custName': '香港商凱渤維思有限公司台灣分公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '1000000',
#     'salaryHigh': '1200000',
#     'salaryDesc': '年薪1,000,000~1,200,000元',
#     's10': '60',
#     'appearDate': '20220920',
#     'appearDateDesc': '9/20',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': 'Cubewise是一家全球化的諮詢公司，專注於基於TM1，説明各大知名集團實現智能化經營管理分析，優化管理流程。 Web developer崗位主要涉及開發TM1 web应用开发，也会涉及到front-end UI/Template/Dashboard模組。基於顧問團隊搭建好的模型，配合顧問團隊在前端方面更好的幫助客戶使用我們的分析系統。 我們與各行業龍頭企業合作，幫助他們解決問題的同時學習接觸到到更多各行業頂尖企業相關技能。\n\nJob Requirement\n\n1.至少3年以上的前端體驗扎實的開發經驗，对于前端架构有所了解 At least 3+ years front-end solid development experience, better if knows the front-end architecture.\n2.精通 React JS, jQuery, JavaScript , HTML, CSS\tProficiency in React JS, jQuery, JavaScript, HTML, CSS  JS \n3.有Bootstrap, UI-Bootstrap, D3 / nvD3, Charting, Sheet JS等方面的熟悉和實踐經驗 Familiar and hands-on experience on using Bootstrap, UI-Bootstrap, D3 / nvD3, Charting, Sheet\n4.使用 GitHub 或類似的原始程式碼管理工具的經驗, 熟悉前端網頁程式開發和部署週期管理  Experience on using GitHub or similar source control tool and familiar with front-end web development and deployment cycle management \n5.具有各種 web 服務 (Tomcat、Nginx等)、瀏覽器 (Chrome、火狐、Safari 等) 和移動平臺 (Android、iOS 等) 的經驗, 以及每個用戶端的性能和頁面優化  Experience with various web services (Tomcat, Nginx etc.), browsers (Chrome, Firefox, Safari, etc) and mobile platform (Android, iOS etc.), as well as performance and page optimization on each client \n6.能够通过单元测试实现高性能、可重用的组件。Able to implement high performing, reusable components with unit test.\n7.有Python（Flask）开发经验加分  Ideal candidates would also have experience in back-end web development like Python\n8.具有團隊合作精神, 能夠與泛亞洲和國際團隊一起工作 Self-motivated team player able to work well with pan Asian and international teams \n9.強烈的責任感和學習渴望 Strong sense of responsibility and eagerness to learn  \n',
#     'tags': [],
#     'landmark': '距捷運善導寺站320公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6aiim?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/6aiim?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bkgaj?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '前端開發工程師（React JS）',
#     'custNameRaw': '香港商凱渤維思有限公司台灣分公司',
#     'lon': '121.5264634',
#     'lat': '25.0455757',
#     'remoteWorkType': 0,
#     'major': ['其他數學及電算機科學相關', '資訊管理相關', '財稅金融相關']},
#    {'jobType': '0',
#     'jobNo': '12611471',
#     'jobName': '前端工程師(遠端)',
#     'jobNameSnippet': "前端<em class='b-txt--highlight'>工程師</em>(遠端)",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '',
#     'description': ' [[[software]]] development process\n●\tCollaborate with other [[[software]]] engineers, business analysts and [[[software]]] architects to plan,',
#     'optionEdu': '大學',
#     'period': '04',
#     'periodDesc': '3年',
#     'applyCnt': '00004',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000175269',
#     'custName': '頂尖營銷傳媒有限公司',
#     'coIndustry': '1001001006',
#     'coIndustryDesc': '其它軟體及網路相關業',
#     'salaryLow': '0070000',
#     'salaryHigh': '0090000',
#     'salaryDesc': '月薪70,000~90,000元',
#     's10': '50',
#     'appearDate': '20220926',
#     'appearDateDesc': '9/26',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': " <em class='b-txt--highlight'>software</em> development process\n●\tCollaborate with other <em class='b-txt--highlight'>software</em> engineers, business analysts and <em class='b-txt--highlight'>software</em> architects to plan,",
#     'tags': ['員工10人', '遠端工作'],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7ib2n?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7ib2n?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6blqjp?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '前端工程師(遠端)',
#     'custNameRaw': '頂尖營銷傳媒有限公司',
#     'lon': '121.5198716',
#     'lat': '25.0421407',
#     'remoteWorkType': 1,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12373523',
#     'jobName': '後端工程師',
#     'jobNameSnippet': "後端<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '南昌路2段103號4樓之1',
#     'description': '工作內容：\n1.負責管理系統的開發、維護\n2.規劃 API 及撰寫 Swagger API 文件\n3.負責資料庫設計\n4.負責分析、優化系統效能\n5.與企劃團隊溝通合作，分析策劃需求並完成功能的程式設計與實現\n\n條件特質：\n1. 1 年以上 go 開發經驗\n2. 1 年以上 HTTP 伺服器開發經驗\n3. 持續學習新知，勇於嘗試，增進工作流程與效率\n4. 能獨立開發完整的中小型專案尤佳\n5. 具備團隊溝通、獨立分析問題並解決之能力\n\n[加分] 程式語⾔與技術：\n1. Websocket、HTTP 等網路協定\n2. Cache and Messaging System: Redis, Memcache\n3. Database: MySQL, NoSQL\n5. Version Control System: GitLab\n',
#     'optionEdu': '大學',
#     'period': '02',
#     'periodDesc': '1年',
#     'applyCnt': '00002',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000174341',
#     'custName': '遊戲雲端科技股份有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0050000',
#     'salaryHigh': '9999999',
#     'salaryDesc': '月薪50,000元以上',
#     's10': '50',
#     'appearDate': '20220925',
#     'appearDateDesc': '9/25',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': '工作內容：\n1.負責管理系統的開發、維護\n2.規劃 API 及撰寫 Swagger API 文件\n3.負責資料庫設計\n4.負責分析、優化系統效能\n5.與企劃團隊溝通合作，分析策劃需求並完成功能的程式設計與實現\n\n條件特質：\n1. 1 年以上 go 開發經驗\n2. 1 年以上 HTTP 伺服器開發經驗\n3. 持續學習新知，勇於嘗試，增進工作流程與效率\n4. 能獨立開發完整的中小型專案尤佳\n5. 具備團隊溝通、獨立分析問題並解決之能力\n\n[加分] 程式語⾔與技術：\n1. Websocket、HTTP 等網路協定\n2. Cache and Messaging System: Redis, Memcache\n3. Database: MySQL, NoSQL\n5. Version Control System: GitLab\n',
#     'tags': ['員工22人'],
#     'landmark': '距捷運古亭站140公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7d7gz?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7d7gz?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6blptx?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '後端工程師',
#     'custNameRaw': '遊戲雲端科技股份有限公司',
#     'lon': '121.5214732',
#     'lat': '25.0267187',
#     'remoteWorkType': 0,
#     'major': ['資訊工程相關', '其他數學及電算機科學相關', '應用數學相關']},
#    {'jobType': '0',
#     'jobNo': '11612204',
#     'jobName': '物聯網後端工程師 IoT Back-end Developer',
#     'jobNameSnippet': "物聯網後端<em class='b-txt--highlight'>工程師</em> IoT Back-end Developer",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '思源街18號A棟406室',
#     'description': '- 了解各IoT領域的痛點，解決工業領域常見的問題\r\n- 負責將新需求轉化成產品功能，規劃建立相對應的[[[軟體]]]元件，包含線上部署產品化等\r\n- 開發維護全球範圍的雲端服務架構，包含AI and IoT應用框架，與機器學習應用框架',
#     'optionEdu': '大學',
#     'period': '06',
#     'periodDesc': '5年',
#     'applyCnt': '00001',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000129501',
#     'custName': '慧景科技股份有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '1200000',
#     'salaryHigh': '2000000',
#     'salaryDesc': '年薪1,200,000~2,000,000元',
#     's10': '60',
#     'appearDate': '20220923',
#     'appearDateDesc': '9/23',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "- 了解各IoT領域的痛點，解決工業領域常見的問題\r\n- 負責將新需求轉化成產品功能，規劃建立相對應的<em class='b-txt--highlight'>軟體</em>元件，包含線上部署產品化等\r\n- 開發維護全球範圍的雲端服務架構，包含AI and IoT應用框架，與機器學習應用框架",
#     'tags': ['員工16人'],
#     'landmark': '距捷運公館站470公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6ww18?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/6ww18?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bkr8d?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '物聯網後端工程師 IoT Back-end Developer',
#     'custNameRaw': '慧景科技股份有限公司',
#     'lon': '121.5297208',
#     'lat': '25.0136964',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12962229',
#     'jobName': '遊戲後端開發資深工程師/工程師(台北)',
#     'jobNameSnippet': "遊戲後端開發資深<em class='b-txt--highlight'>工程師</em>/<em class='b-txt--highlight'>工程師</em>(台北)",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '和平東路一段180號9樓',
#     'description': '1.遊戲後端開發或維護經驗。\n2.有使用以下其中一種Golang、Java、C/C++開發經驗。熟悉Golang尤佳。\n3.熟悉Redis開發。\n4.熟悉開發過程中經常用到的 JSON、RESTful API、Redis、Github、Web Scoket、Docker等。\n5.熟悉常見資料結構及演算法。\n6.有高併發、高可用、分散式服務開發經驗者為佳。\n7.良好的團隊合作與溝通能力並樂於學習新技術。',
#     'optionEdu': '大學',
#     'period': '02',
#     'periodDesc': '1年',
#     'applyCnt': '00003',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000144775',
#     'custName': '大鏞科技股份有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0000000',
#     'salaryHigh': '0000000',
#     'salaryDesc': '待遇面議',
#     's10': '10',
#     'appearDate': '20220920',
#     'appearDateDesc': '9/20',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': '1.遊戲後端開發或維護經驗。\n2.有使用以下其中一種Golang、Java、C/C++開發經驗。熟悉Golang尤佳。\n3.熟悉Redis開發。\n4.熟悉開發過程中經常用到的 JSON、RESTful API、Redis、Github、Web Scoket、Docker等。\n5.熟悉常見資料結構及演算法。\n6.有高併發、高可用、分散式服務開發經驗者為佳。\n7.良好的團隊合作與溝通能力並樂於學習新技術。',
#     'tags': [],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7ptpx?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7ptpx?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bl30n?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '遊戲後端開發資深工程師/工程師(台北)',
#     'custNameRaw': '大鏞科技股份有限公司',
#     'lon': '121.5296407',
#     'lat': '25.026207',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12833092',
#     'jobName': '前端工程師_FrontEnd Engineer_Yory',
#     'jobNameSnippet': "前端<em class='b-txt--highlight'>工程師</em>_FrontEnd Engineer_Yory",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '羅斯福路2段9號11樓之1',
#     'description': '【關於我們】\n幫你優集團 (BoniO) 是教育創新的團隊，用科技x媒體一起解決教育問題。繼PaGamO後將推出另一教育創新產品Yory，鼓勵學生拓展多元探索視野與留下個人學思歷程。我們正需要對教育科技有熱忱的你，一起加入我們迎接各種創新挑戰，共同打造優質學習系統、創造品牌影響力。 \n\nYory 優歷 - 產品介紹  \n學習歷程檔案為 108 課綱中的重點項⽬，但教學現場實際狀況⼤多無所適從，老師與學⽣不知道該如何撰寫才能獲得⼤學老師較多的青睞。Yory 優歷從解決學⽣在學習歷程檔案上的困擾出發，先透過 AI 幫助學⽣「寫得出來」，撰寫過程中透過系統引導「養成⾃我覺察 與反思能⼒」，最後提供「探索系統」幫助學⽣更認識⾃⼰、更有信⼼選擇⾃⼰的未來。  \n\n【AI ⽂字評鑑】 Yory 優歷致⼒於協助學⽣快速掌握學習歷程的寫作⽅向與重點，透過 AI ⽂字分析，讓學⽣即使沒有老師指導，也有機會寫出結構完整、陳述清晰的學習歷程檔案。  \n\n【探索系統】 我們也希望在解決學⽣們的學習歷程檔案剛需問題過程中，引導學⽣多⽅⾃我探索，包含了解⼤學各學系的真實狀況與學習內容、未來職業發展⽅向等等，讓學⽣對於感興趣的領域「Do Something」從中了解⾃⼰是否真的喜歡？還是與想像中不同。讓學⽣「成為⾃⼰想要的樣⼦」  \n\nYory優歷網站連結：https://www.yory.school \n\n- 我們如何開發產品：為了讓產品持續前進，真正解決使⽤者問題，帶給使⽤者最好的體驗，在進⾏任何改動前，會進⾏以下步驟： \n1. 為什麼要做？確認⽬標（要解決什麼問題？TA 會使⽤或購買嗎？）  \n2. 針對問題做研究、做功課、訪談（商業⾯、⽤⼾⾯）  \n3. 整理研究成果，初步規劃，製作線框圖或原型  \n4. 邀請 Design、RD 參與問題、討論、找出盲點  \n5. 定義出真實問題、需求或痛點  \n6. 依專案複雜度決定是否執⾏易⽤性測試  \n7. 產出解法  \n8. 開需求票（我們使⽤ Redmine 管理）  \n9. 掌握所有步驟時間，不因前期作業流程延誤開發  \n\n- 開發團隊流程：以帶來更好的產品並讓⼯程師能持續成長為前提，我們運⾏ Scrum 並以兩週為⼀個 Sprint 單位，在這段過程中，您將依此流程專注於解決所⾯對的任務： \n1. 確認理解任務內容  \n2. 思考實作⽅式並進⾏開發  \n3. 確保所撰寫的 Test Case 有涵蓋到正反向及各種邊界情境  \n4. 將成果發 Pull Request 並持續與 Reviewer 討論 （我們非常重視 Code Review，互相討論不僅能幫助團隊快速成長，也讓產品體 驗更上層樓）  \n5. 測試環境再確認，確保順利上線提升⽤⼾體驗  \n\n- 產出品質控制： \n每個 Sprint 會有⼀次 Release，中間會經過相當嚴謹的品質控管： \n 1. 開發機 (Dev): PR Merge 後即會更新⾄開發機，PM可快速進⾏驗證，若有須微調的項⽬也能快速反應  \n2. 測試機 (Staging): 該 Sprint 的所有任務都在上⾯，PM可以看⾒本次 Release 的全貌，QA 也會在此階段進⾏各項測試，檢查是否有改 A 壞 B 的狀況，確保⽤⼾體驗良好，RD 也將以修正 staging issues 為優先  \n3. 預正式機 (Pre-Production): 夥伴在 Staging 驗證完畢後，會將本次 Release 上到與正式環境完全相同的預正式機，進⾏全⾯的最後測試  \n4. 正式機（Production): 前三個步驟所有⾓⾊都依照⾃⼰的守備防區確認無誤後才可上線，確保使⽤者有最好的體驗  \n\n⼯作內容：  \n• 配合產品⽬標進⾏新功能模組開發  \n• 配合產品經理持續優化現有產品  \n• 共同討論、制定前端技術架構  \n• 持續優化產品效能與提⾼穩定度  \n• 根據設計稿製作前端畫⾯（我們使⽤Figma）  \n• 與後端夥伴討論、實作串接 API  \n• 撰寫測試    \n\n我們期待你:  \n• 具備獨立或主導完成功能模組經驗  \n• 2 年以上現代網站開發經驗 我們使⽤ Nextjs開發，以 React 為主，UI Framework 暫時為 MaterialUIv4 。但只要你對其他框架有夠深入的理解與開發經驗 Svelt / Remix / Flutter / Nuxt / Angular / Vue 或其他，都歡迎來聊聊 \n• 熟悉⾃動化測試  ',
#     'optionEdu': '大學',
#     'period': '03',
#     'periodDesc': '2年',
#     'applyCnt': '00004',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000044010',
#     'custName': '英屬維京群島商幫你優股份有限公司台灣分公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0900000',
#     'salaryHigh': '1200000',
#     'salaryDesc': '年薪900,000~1,200,000元',
#     's10': '60',
#     'appearDate': '20220920',
#     'appearDateDesc': '9/20',
#     'optionZone': '262144',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': '【關於我們】\n幫你優集團 (BoniO) 是教育創新的團隊，用科技x媒體一起解決教育問題。繼PaGamO後將推出另一教育創新產品Yory，鼓勵學生拓展多元探索視野與留下個人學思歷程。我們正需要對教育科技有熱忱的你，一起加入我們迎接各種創新挑戰，共同打造優質學習系統、創造品牌影響力。 \n\nYory 優歷 - 產品介紹  \n學習歷程檔案為 108 課綱中的重點項⽬，但教學現場實際狀況⼤多無所適從，老師與學⽣不知道該如何撰寫才能獲得⼤學老師較多的青睞。Yory 優歷從解決學⽣在學習歷程檔案上的困擾出發，先透過 AI 幫助學⽣「寫得出來」，撰寫過程中透過系統引導「養成⾃我覺察 與反思能⼒」，最後提供「探索系統」幫助學⽣更認識⾃⼰、更有信⼼選擇⾃⼰的未來。  \n\n【AI ⽂字評鑑】 Yory 優歷致⼒於協助學⽣快速掌握學習歷程的寫作⽅向與重點，透過 AI ⽂字分析，讓學⽣即使沒有老師指導，也有機會寫出結構完整、陳述清晰的學習歷程檔案。  \n\n【探索系統】 我們也希望在解決學⽣們的學習歷程檔案剛需問題過程中，引導學⽣多⽅⾃我探索，包含了解⼤學各學系的真實狀況與學習內容、未來職業發展⽅向等等，讓學⽣對於感興趣的領域「Do Something」從中了解⾃⼰是否真的喜歡？還是與想像中不同。讓學⽣「成為⾃⼰想要的樣⼦」  \n\nYory優歷網站連結：https://www.yory.school \n\n- 我們如何開發產品：為了讓產品持續前進，真正解決使⽤者問題，帶給使⽤者最好的體驗，在進⾏任何改動前，會進⾏以下步驟： \n1. 為什麼要做？確認⽬標（要解決什麼問題？TA 會使⽤或購買嗎？）  \n2. 針對問題做研究、做功課、訪談（商業⾯、⽤⼾⾯）  \n3. 整理研究成果，初步規劃，製作線框圖或原型  \n4. 邀請 Design、RD 參與問題、討論、找出盲點  \n5. 定義出真實問題、需求或痛點  \n6. 依專案複雜度決定是否執⾏易⽤性測試  \n7. 產出解法  \n8. 開需求票（我們使⽤ Redmine 管理）  \n9. 掌握所有步驟時間，不因前期作業流程延誤開發  \n\n- 開發團隊流程：以帶來更好的產品並讓⼯程師能持續成長為前提，我們運⾏ Scrum 並以兩週為⼀個 Sprint 單位，在這段過程中，您將依此流程專注於解決所⾯對的任務： \n1. 確認理解任務內容  \n2. 思考實作⽅式並進⾏開發  \n3. 確保所撰寫的 Test Case 有涵蓋到正反向及各種邊界情境  \n4. 將成果發 Pull Request 並持續與 Reviewer 討論 （我們非常重視 Code Review，互相討論不僅能幫助團隊快速成長，也讓產品體 驗更上層樓）  \n5. 測試環境再確認，確保順利上線提升⽤⼾體驗  \n\n- 產出品質控制： \n每個 Sprint 會有⼀次 Release，中間會經過相當嚴謹的品質控管： \n 1. 開發機 (Dev): PR Merge 後即會更新⾄開發機，PM可快速進⾏驗證，若有須微調的項⽬也能快速反應  \n2. 測試機 (Staging): 該 Sprint 的所有任務都在上⾯，PM可以看⾒本次 Release 的全貌，QA 也會在此階段進⾏各項測試，檢查是否有改 A 壞 B 的狀況，確保⽤⼾體驗良好，RD 也將以修正 staging issues 為優先  \n3. 預正式機 (Pre-Production): 夥伴在 Staging 驗證完畢後，會將本次 Release 上到與正式環境完全相同的預正式機，進⾏全⾯的最後測試  \n4. 正式機（Production): 前三個步驟所有⾓⾊都依照⾃⼰的守備防區確認無誤後才可上線，確保使⽤者有最好的體驗  \n\n⼯作內容：  \n• 配合產品⽬標進⾏新功能模組開發  \n• 配合產品經理持續優化現有產品  \n• 共同討論、制定前端技術架構  \n• 持續優化產品效能與提⾼穩定度  \n• 根據設計稿製作前端畫⾯（我們使⽤Figma）  \n• 與後端夥伴討論、實作串接 API  \n• 撰寫測試    \n\n我們期待你:  \n• 具備獨立或主導完成功能模組經驗  \n• 2 年以上現代網站開發經驗 我們使⽤ Nextjs開發，以 React 為主，UI Framework 暫時為 MaterialUIv4 。但只要你對其他框架有夠深入的理解與開發經驗 Svelt / Remix / Flutter / Nuxt / Angular / Vue 或其他，都歡迎來聊聊 \n• 熟悉⾃動化測試  ',
#     'tags': ['員工100人', '遠端工作'],
#     'landmark': '距捷運古亭站300公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7n22s?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7n22s?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bix9m?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '前端工程師_FrontEnd Engineer_Yory',
#     'custNameRaw': '英屬維京群島商幫你優股份有限公司台灣分公司',
#     'lon': '121.5213599',
#     'lat': '25.0289099',
#     'remoteWorkType': 2,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12856743',
#     'jobName': 'AI工程師(台北)',
#     'jobNameSnippet': "AI<em class='b-txt--highlight'>工程師</em>(台北)",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '',
#     'description': '1.資料處理與模型建立（訊號處理、影像處理、資料庫語法、資料庫規劃、機器學習、深度學習、NLP、NLU、技術文件撰寫、等）\n2.AI技術研發\n3.模型與系統優化與最佳化\n4. 其它主管交辦事項。',
#     'optionEdu': '不拘',
#     'period': '00',
#     'periodDesc': '不拘',
#     'applyCnt': '00005',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000161737',
#     'custName': '萊泀股份有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0000000',
#     'salaryHigh': '0000000',
#     'salaryDesc': '待遇面議',
#     's10': '10',
#     'appearDate': '20220924',
#     'appearDateDesc': '9/24',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': '1.資料處理與模型建立（訊號處理、影像處理、資料庫語法、資料庫規劃、機器學習、深度學習、NLP、NLU、技術文件撰寫、等）\n2.AI技術研發\n3.模型與系統優化與最佳化\n4. 其它主管交辦事項。',
#     'tags': [],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7nkbr?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7nkbr?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6blg3t?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'AI工程師(台北)',
#     'custNameRaw': '萊泀股份有限公司',
#     'lon': '121.5198716',
#     'lat': '25.0421407',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12936471',
#     'jobName': '軟體測試工程師 Software Test Engineer',
#     'jobNameSnippet': "<em class='b-txt--highlight'>軟體</em>測試<em class='b-txt--highlight'>工程師</em> <em class='b-txt--highlight'>Software</em> Test Engineer",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '仁愛路二段2號7樓',
#     'description': '.\t充分的耐心與細心\n5.\t主動積極，有良好的溝通能力\n\n【加分項】\n1.\tRust 程式設計能力\n2.\t有CI / CD 的導入經驗\n\n＊可為專職自動化[[[軟體]]]測試[[[工程師]]]，或者，若有意願，加入一段時間後轉職為C++ [[[軟體開發工程師]]]。',
#     'optionEdu': '不拘',
#     'period': '04',
#     'periodDesc': '3年',
#     'applyCnt': '00003',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000098433',
#     'custName': '威旭資訊有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0060000',
#     'salaryHigh': '0100000',
#     'salaryDesc': '月薪60,000~100,000元',
#     's10': '50',
#     'appearDate': '20220920',
#     'appearDateDesc': '9/20',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': ".\t充分的耐心與細心\n5.\t主動積極，有良好的溝通能力\n\n【加分項】\n1.\tRust 程式設計能力\n2.\t有CI / CD 的導入經驗\n\n＊可為專職自動化<em class='b-txt--highlight'>軟體</em>測試<em class='b-txt--highlight'>工程師</em>，或者，若有意願，加入一段時間後轉職為C++ <em class='b-txt--highlight'>軟體開發工程師</em>。",
#     'tags': ['員工60人'],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7p9uf?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7p9uf?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bk39d?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '軟體測試工程師 Software Test Engineer',
#     'custNameRaw': '威旭資訊有限公司',
#     'lon': '121.5253272',
#     'lat': '25.0380886',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12883522',
#     'jobName': '資深測試工程師 | Senior QA Engineer',
#     'jobNameSnippet': "資深測試<em class='b-txt--highlight'>工程師</em> | Senior QA Engineer",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '武昌街一段18號8樓',
#     'description': 'Omnichat (原Easychat）創辦於 2017年，是來自香港的新創企業，專注於發展全通路對話式商務 (Omnichannel Chat Commerce)。涉及技術和產品包括串接官網對話及整合不同社群通訊[[[軟體]]]， 跨渠道用戶數據追蹤，全通',
#     'optionEdu': '專科',
#     'period': '05',
#     'periodDesc': '4年',
#     'applyCnt': '00001',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000174956',
#     'custName': '全通路科技有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0700000',
#     'salaryHigh': '1000000',
#     'salaryDesc': '年薪700,000~1,000,000元',
#     's10': '60',
#     'appearDate': '20220919',
#     'appearDateDesc': '9/19',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "Omnichat (原Easychat）創辦於 2017年，是來自香港的新創企業，專注於發展全通路對話式商務 (Omnichannel Chat Commerce)。涉及技術和產品包括串接官網對話及整合不同社群通訊<em class='b-txt--highlight'>軟體</em>， 跨渠道用戶數據追蹤，全通",
#     'tags': ['員工50人', '遠端工作'],
#     'landmark': '距捷運台大醫院站430公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7o4zm?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7o4zm?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6blqb0?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '資深測試工程師 | Senior QA Engineer',
#     'custNameRaw': '全通路科技有限公司',
#     'lon': '121.5125261',
#     'lat': '25.0439381',
#     'remoteWorkType': 2,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '13018952',
#     'jobName': '前端工程師｜Frontend Engineer',
#     'jobNameSnippet': "前端<em class='b-txt--highlight'>工程師</em>｜Frontend Engineer",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '武昌街一段18號8樓',
#     'description': '\n・熟悉 Javascript / HTML / CSS\n・熟悉任一 Javascript 前端框架 (Vue.js 為佳)\n・熱愛前端[[[軟體工程]]]開發的工作內容，對鑽研新前端技術有熱情\n・必須能適應團隊討論及合作工作模式\n・具有良好的技術溝通能力，能清',
#     'optionEdu': '專科',
#     'period': '02',
#     'periodDesc': '1年',
#     'applyCnt': '00005',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000174956',
#     'custName': '全通路科技有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0700000',
#     'salaryHigh': '0900000',
#     'salaryDesc': '年薪700,000~900,000元',
#     's10': '60',
#     'appearDate': '20220919',
#     'appearDateDesc': '9/19',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "\n・熟悉 Javascript / HTML / CSS\n・熟悉任一 Javascript 前端框架 (Vue.js 為佳)\n・熱愛前端<em class='b-txt--highlight'>軟體工程</em>開發的工作內容，對鑽研新前端技術有熱情\n・必須能適應團隊討論及合作工作模式\n・具有良好的技術溝通能力，能清",
#     'tags': ['員工50人', '遠端工作'],
#     'landmark': '距捷運台大醫院站430公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7r1hk?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7r1hk?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6blqb0?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '前端工程師｜Frontend Engineer',
#     'custNameRaw': '全通路科技有限公司',
#     'lon': '121.5125261',
#     'lat': '25.0439381',
#     'remoteWorkType': 2,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '11541873',
#     'jobName': 'Python 後端工程師',
#     'jobNameSnippet': "Python 後端<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '寧波東街1號6樓',
#     'description': '# Job Description\n\n## 工作內容\n\n### 描述\n\n- 開發手機串接API\n- 與機器學習[[[工程師]]]合作、討論、開發\n- 行政人員後台畫面\n- 程式部署、文件撰寫\n\n### Technical Stack\n\n- Redmine,',
#     'optionEdu': '專科',
#     'period': '03',
#     'periodDesc': '2年',
#     'applyCnt': '00001',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000034351',
#     'custName': '凸版蓋特資訊股份有限公司',
#     'coIndustry': '1001001003',
#     'coIndustryDesc': '網際網路相關業',
#     'salaryLow': '0000000',
#     'salaryHigh': '0000000',
#     'salaryDesc': '待遇面議',
#     's10': '10',
#     'appearDate': '20220926',
#     'appearDateDesc': '9/26',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "# Job Description\n\n## 工作內容\n\n### 描述\n\n- 開發手機串接API\n- 與機器學習<em class='b-txt--highlight'>工程師</em>合作、討論、開發\n- 行政人員後台畫面\n- 程式部署、文件撰寫\n\n### Technical Stack\n\n- Redmine,",
#     'tags': ['員工28人'],
#     'landmark': '距捷運中正紀念堂站140公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6vdrl?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/6vdrl?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6biptb?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'Python 後端工程師',
#     'custNameRaw': '凸版蓋特資訊股份有限公司',
#     'lon': '121.5194075',
#     'lat': '25.0319251',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12833061',
#     'jobName': '全端工程師_FullStack Engineer_Yory',
#     'jobNameSnippet': "全端<em class='b-txt--highlight'>工程師</em>_FullStack Engineer_Yory",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '羅斯福路2段9號11樓之1',
#     'description': '【關於我們】\n幫你優集團 (BoniO) 是教育創新的團隊，用科技x媒體一起解決教育問題。繼PaGamO後將推出另一教育創新產品Yory，鼓勵學生拓展多元探索視野與留下個人學思歷程。我們正需要對教育科技有熱忱的你，一起加入我們迎接各種創新挑戰，共同打造優質學習系統、創造品牌影響力。 \n\nYory 優歷 - 產品介紹  \n學習歷程檔案為 108 課綱中的重點項⽬，但教學現場實際狀況⼤多無所適從，老師與學⽣不知道該如何撰寫才能獲得⼤學老師較多的青睞。Yory優歷從解決學⽣在學習歷程檔案上的困擾出發，先透過 AI 幫助學⽣「寫得出來」，撰寫過程中透過系統引導「養成⾃我覺察 與反思能⼒」，最後提供「探索系統」幫助學⽣更認識⾃⼰、更有信⼼選擇⾃⼰的未來。  \n\n【AI ⽂字評鑑】 Yory 優歷致⼒於協助學⽣快速掌握學習歷程的寫作⽅向與重點，透過 AI ⽂字分析，讓學⽣即使沒有老師指導，也有機會寫出結構完整、陳述清晰的學習歷程檔案。  \n\n【探索系統】 我們也希望在解決學⽣們的學習歷程檔案剛需問題過程中，引導學⽣多⽅⾃我探索，包含了解⼤學各學系的真實狀況與學習內容、未來職業發展⽅向等等，讓學⽣對於感興趣的領域「Do Something」從中了解⾃⼰是否真的喜歡？還是與想像中不同。讓學⽣「成為⾃⼰想要的樣⼦」  \n\nYory優歷網站連結：https://www.yory.school \n\n- 我們如何開發產品： 為了讓產品持續前進，真正解決使⽤者問題，帶給使⽤者最好的體驗，在進⾏任何改動前，會進⾏以下步驟： \n1. 為什麼要做？確認⽬標（要解決什麼問題？TA 會使⽤或購買嗎？）  \n2. 針對問題做研究、做功課、訪談（商業⾯、⽤⼾⾯）  \n3. 整理研究成果，初步規劃，製作線框圖或原型  \n4. 邀請 Design、RD 參與問題、討論、找出盲點  \n5. 定義出真實問題、需求或痛點  \n6. 依專案複雜度決定是否執⾏易⽤性測試  \n7. 產出解法  \n8. 開需求票（我們使⽤ Redmine 管理）  \n9. 掌握所有步驟時間，不因前期作業流程延誤開發  \n\n- 開發團隊流程：以帶來更好的產品並讓⼯程師能持續成長為前提，我們運⾏ Scrum 並以兩週為⼀個 Sprint 單位，在這段過程中，您將依此流程專注於解決所⾯對的任務： \n1. 確認理解任務內容  \n2. 思考實作⽅式並進⾏開發  \n3. 確保所撰寫的 Test Case 有涵蓋到正反向及各種邊界情境  \n4. 將成果發 Pull Request 並持續與 Reviewer 討論 （我們非常重視 Code Review，互相討論不僅能幫助團隊快速成長，也讓產品體驗更上層樓）  \n5. 測試環境再確認，確保順利上線提升⽤⼾體驗  \n\n- 產出品質控制： \n每個 Sprint 會有⼀次 Release，中間會經過相當嚴謹的品質控管： \n 1. 開發機 (Dev): PR Merge 後即會更新⾄開發機，PM可快速進⾏驗證，若有須微調的項⽬也能快速反應  \n2. 測試機 (Staging): 該 Sprint 的所有任務都在上⾯，PM可以看⾒本次 Release 的全貌，QA 也會在此階段進⾏各項測試，檢查是否有改 A 壞 B 的狀況，確保⽤⼾體驗良好，RD 也將以修正 staging issues 為優先  \n3. 預正式機 (Pre-Production): 夥伴在 Staging 驗證完畢後，會將本次 Release 上到與正式環境完全相同的預正式機，進⾏全⾯的最後測試  \n4. 正式機（Production): 前三個步驟所有⾓⾊都依照⾃⼰的守備防區確認無誤後才可上線，確保使⽤者有最好的體驗  \n\n⼯作內容：  \n• 配合產品⽬標進⾏新功能模組開發 \n• 配合產品經理持續優化現有產品  \n• 共同討論、制定技術架構  \n• 持續優化產品效能與提⾼穩定度 \n• API / micro-services 開發、優化  \n• 前端畫⾯製作  \n• 撰寫測試  \n• 管理 AWS 各項服務（Optional）  \n\n 我們期待你:  \n• 具備獨立或主導完成功能模組經驗  \n• 2 年以上現代網站開發經驗 (我們使⽤ Nextjs 開發。但只要你對其他語⾔或 Framework 有夠深入的理解與開 發經驗 Ruby on Rails / Django / Go 或其他，都歡迎來聊聊～）  \n• 熟悉任⼀款資料庫設計並具備優化經驗（我們使⽤ Mongodb）  \n• 熟悉⾃動化測試  \n• 具備雲端伺服器建置經驗  ',
#     'optionEdu': '大學',
#     'period': '03',
#     'periodDesc': '2年',
#     'applyCnt': '00002',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000044010',
#     'custName': '英屬維京群島商幫你優股份有限公司台灣分公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '1200000',
#     'salaryHigh': '2000000',
#     'salaryDesc': '年薪1,200,000~2,000,000元',
#     's10': '60',
#     'appearDate': '20220920',
#     'appearDateDesc': '9/20',
#     'optionZone': '262144',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': '【關於我們】\n幫你優集團 (BoniO) 是教育創新的團隊，用科技x媒體一起解決教育問題。繼PaGamO後將推出另一教育創新產品Yory，鼓勵學生拓展多元探索視野與留下個人學思歷程。我們正需要對教育科技有熱忱的你，一起加入我們迎接各種創新挑戰，共同打造優質學習系統、創造品牌影響力。 \n\nYory 優歷 - 產品介紹  \n學習歷程檔案為 108 課綱中的重點項⽬，但教學現場實際狀況⼤多無所適從，老師與學⽣不知道該如何撰寫才能獲得⼤學老師較多的青睞。Yory優歷從解決學⽣在學習歷程檔案上的困擾出發，先透過 AI 幫助學⽣「寫得出來」，撰寫過程中透過系統引導「養成⾃我覺察 與反思能⼒」，最後提供「探索系統」幫助學⽣更認識⾃⼰、更有信⼼選擇⾃⼰的未來。  \n\n【AI ⽂字評鑑】 Yory 優歷致⼒於協助學⽣快速掌握學習歷程的寫作⽅向與重點，透過 AI ⽂字分析，讓學⽣即使沒有老師指導，也有機會寫出結構完整、陳述清晰的學習歷程檔案。  \n\n【探索系統】 我們也希望在解決學⽣們的學習歷程檔案剛需問題過程中，引導學⽣多⽅⾃我探索，包含了解⼤學各學系的真實狀況與學習內容、未來職業發展⽅向等等，讓學⽣對於感興趣的領域「Do Something」從中了解⾃⼰是否真的喜歡？還是與想像中不同。讓學⽣「成為⾃⼰想要的樣⼦」  \n\nYory優歷網站連結：https://www.yory.school \n\n- 我們如何開發產品： 為了讓產品持續前進，真正解決使⽤者問題，帶給使⽤者最好的體驗，在進⾏任何改動前，會進⾏以下步驟： \n1. 為什麼要做？確認⽬標（要解決什麼問題？TA 會使⽤或購買嗎？）  \n2. 針對問題做研究、做功課、訪談（商業⾯、⽤⼾⾯）  \n3. 整理研究成果，初步規劃，製作線框圖或原型  \n4. 邀請 Design、RD 參與問題、討論、找出盲點  \n5. 定義出真實問題、需求或痛點  \n6. 依專案複雜度決定是否執⾏易⽤性測試  \n7. 產出解法  \n8. 開需求票（我們使⽤ Redmine 管理）  \n9. 掌握所有步驟時間，不因前期作業流程延誤開發  \n\n- 開發團隊流程：以帶來更好的產品並讓⼯程師能持續成長為前提，我們運⾏ Scrum 並以兩週為⼀個 Sprint 單位，在這段過程中，您將依此流程專注於解決所⾯對的任務： \n1. 確認理解任務內容  \n2. 思考實作⽅式並進⾏開發  \n3. 確保所撰寫的 Test Case 有涵蓋到正反向及各種邊界情境  \n4. 將成果發 Pull Request 並持續與 Reviewer 討論 （我們非常重視 Code Review，互相討論不僅能幫助團隊快速成長，也讓產品體驗更上層樓）  \n5. 測試環境再確認，確保順利上線提升⽤⼾體驗  \n\n- 產出品質控制： \n每個 Sprint 會有⼀次 Release，中間會經過相當嚴謹的品質控管： \n 1. 開發機 (Dev): PR Merge 後即會更新⾄開發機，PM可快速進⾏驗證，若有須微調的項⽬也能快速反應  \n2. 測試機 (Staging): 該 Sprint 的所有任務都在上⾯，PM可以看⾒本次 Release 的全貌，QA 也會在此階段進⾏各項測試，檢查是否有改 A 壞 B 的狀況，確保⽤⼾體驗良好，RD 也將以修正 staging issues 為優先  \n3. 預正式機 (Pre-Production): 夥伴在 Staging 驗證完畢後，會將本次 Release 上到與正式環境完全相同的預正式機，進⾏全⾯的最後測試  \n4. 正式機（Production): 前三個步驟所有⾓⾊都依照⾃⼰的守備防區確認無誤後才可上線，確保使⽤者有最好的體驗  \n\n⼯作內容：  \n• 配合產品⽬標進⾏新功能模組開發 \n• 配合產品經理持續優化現有產品  \n• 共同討論、制定技術架構  \n• 持續優化產品效能與提⾼穩定度 \n• API / micro-services 開發、優化  \n• 前端畫⾯製作  \n• 撰寫測試  \n• 管理 AWS 各項服務（Optional）  \n\n 我們期待你:  \n• 具備獨立或主導完成功能模組經驗  \n• 2 年以上現代網站開發經驗 (我們使⽤ Nextjs 開發。但只要你對其他語⾔或 Framework 有夠深入的理解與開 發經驗 Ruby on Rails / Django / Go 或其他，都歡迎來聊聊～）  \n• 熟悉任⼀款資料庫設計並具備優化經驗（我們使⽤ Mongodb）  \n• 熟悉⾃動化測試  \n• 具備雲端伺服器建置經驗  ',
#     'tags': ['員工100人', '遠端工作'],
#     'landmark': '距捷運古亭站300公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7n21x?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7n21x?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bix9m?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '全端工程師_FullStack Engineer_Yory',
#     'custNameRaw': '英屬維京群島商幫你優股份有限公司台灣分公司',
#     'lon': '121.5213599',
#     'lat': '25.0289099',
#     'remoteWorkType': 2,
#     'major': []},
#    {'jobType': '2',
#     'jobNo': '10292898',
#     'jobName': 'JAVA 軟體工程師',
#     'jobNameSnippet': "JAVA <em class='b-txt--highlight'>軟體工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '許昌街17號18樓之1',
#     'description': '1.產險核心及週邊系統開發、測試及維護。 \r\n2.依據分析文件完成[[[軟體]]]程式開發。\r\n3.進行[[[軟體]]]之測試與修改。\r\n4.協助新技術的引進及系統優化。\r\n5.梳理業務需求並予以文件規格化。',
#     'optionEdu': '大學',
#     'period': '04',
#     'periodDesc': '3年',
#     'applyCnt': '00000',
#     'applyDesc': '0~5人應徵',
#     'custNo': '27938888000',
#     'custName': '中國信託產物保險股份有限公司',
#     'coIndustry': '1004003002',
#     'coIndustryDesc': '產物保險業',
#     'salaryLow': '0000000',
#     'salaryHigh': '0000000',
#     'salaryDesc': '待遇面議',
#     's10': '10',
#     'appearDate': '20220921',
#     'appearDateDesc': '9/21',
#     'optionZone': '4096',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "1.產險核心及週邊系統開發、測試及維護。 \r\n2.依據分析文件完成<em class='b-txt--highlight'>軟體</em>程式開發。\r\n3.進行<em class='b-txt--highlight'>軟體</em>之測試與修改。\r\n4.協助新技術的引進及系統優化。\r\n5.梳理業務需求並予以文件規格化。",
#     'tags': ['員工400人'],
#     'landmark': '距捷運台北車站230公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/64m1u?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/64m1u?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/cu23by8?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'JAVA 軟體工程師',
#     'custNameRaw': '中國信託產物保險股份有限公司',
#     'lon': '121.5171',
#     'lat': '25.0457708',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12520684',
#     'jobName': '【北】Frontend Engineer｜Web前端工程師',
#     'jobNameSnippet': "【北】Frontend Engineer｜Web前端<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '',
#     'description': '各種未知問題。\n\n【工作內容】\n1、配合產品經理完成產品功能開發和優化。\n2、配合交互設計師及視覺設計師實現交互效果，配合後台[[[工程師]]]完成應用開發。\n3、負責前端基礎架構、組件抽象。\n\n【具備條件】\n1、大學及以上學歷，資工相關專業背景。\n2、前端基',
#     'optionEdu': '大學',
#     'period': '02',
#     'periodDesc': '1年',
#     'applyCnt': '00003',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000177876',
#     'custName': '大門科技顧問有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0900000',
#     'salaryHigh': '9999999',
#     'salaryDesc': '年薪900,000元以上',
#     's10': '60',
#     'appearDate': '20220921',
#     'appearDateDesc': '9/21',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "各種未知問題。\n\n【工作內容】\n1、配合產品經理完成產品功能開發和優化。\n2、配合交互設計師及視覺設計師實現交互效果，配合後台<em class='b-txt--highlight'>工程師</em>完成應用開發。\n3、負責前端基礎架構、組件抽象。\n\n【具備條件】\n1、大學及以上學歷，資工相關專業背景。\n2、前端基",
#     'tags': ['員工35人', '遠端工作'],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7gd0s?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7gd0s?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6blsk4?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '【北】Frontend Engineer｜Web前端工程師',
#     'custNameRaw': '大門科技顧問有限公司',
#     'lon': '121.5198716',
#     'lat': '25.0421407',
#     'remoteWorkType': 1,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '13009427',
#     'jobName': '【北】(Java)Backend Engineer｜後端工程師',
#     'jobNameSnippet': "【北】(Java)Backend Engineer｜後端<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '',
#     'description': '各種未知問題。\n\n【工作內容】\n1、負責產品開發系統的研發工作。\n2、負責相關產品研發模組的設計、編碼和文檔等工作。\n\n【具備條件】\n1、資訊[[[工程]]]相關專業，大學及以上學歷，2年以上工作經驗。\n2、精通 Java 開發語言，具有的面向對象的開發思想，',
#     'optionEdu': '大學',
#     'period': '03',
#     'periodDesc': '2年',
#     'applyCnt': '00002',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000177876',
#     'custName': '大門科技顧問有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0000000',
#     'salaryHigh': '0000000',
#     'salaryDesc': '待遇面議',
#     's10': '10',
#     'appearDate': '20220920',
#     'appearDateDesc': '9/20',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "各種未知問題。\n\n【工作內容】\n1、負責產品開發系統的研發工作。\n2、負責相關產品研發模組的設計、編碼和文檔等工作。\n\n【具備條件】\n1、資訊<em class='b-txt--highlight'>工程</em>相關專業，大學及以上學歷，2年以上工作經驗。\n2、精通 Java 開發語言，具有的面向對象的開發思想，",
#     'tags': ['員工35人', '遠端工作'],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7qu4z?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7qu4z?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6blsk4?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '【北】(Java)Backend Engineer｜後端工程師',
#     'custNameRaw': '大門科技顧問有限公司',
#     'lon': '121.5198716',
#     'lat': '25.0421407',
#     'remoteWorkType': 1,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '11986383',
#     'jobName': '台南  |  Java後端工程師  |  熟悉Spring Boot | APP 開發設計經驗 |  3-5年以上相關經歷  (KTS_1332)',
#     'jobNameSnippet': "台南  |  Java後端<em class='b-txt--highlight'>工程師</em>  |  熟悉Spring Boot | APP 開發設計經驗 |  3-5年以上相關經歷  (KTS_1332)",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '',
#     'description': '工作內容:\n 1.熟悉微服務設計架構\n2.需有使用Java程式開發五年以上經驗,熟悉Spring Boot(Spring Cloud)框架\n3. 有IoT相關產業經驗\n4.IOS Android APP 系統設計開發\n5.熟悉Git版本控管工具\n\n\n',
#     'optionEdu': '大學',
#     'period': '00',
#     'periodDesc': '不拘',
#     'applyCnt': '00002',
#     'applyDesc': '0~5人應徵',
#     'custNo': '84900645000',
#     'custName': '藝珂人事顧問股份有限公司',
#     'coIndustry': '1009001001',
#     'coIndustryDesc': '人力仲介代徵',
#     'salaryLow': '0900000',
#     'salaryHigh': '1300000',
#     'salaryDesc': '年薪900,000~1,300,000元',
#     's10': '60',
#     'appearDate': '20220920',
#     'appearDateDesc': '9/20',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': '工作內容:\n 1.熟悉微服務設計架構\n2.需有使用Java程式開發五年以上經驗,熟悉Spring Boot(Spring Cloud)框架\n3. 有IoT相關產業經驗\n4.IOS Android APP 系統設計開發\n5.熟悉Git版本控管工具\n\n\n',
#     'tags': [],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/74wr3?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/74wr3?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1303ngy0?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '台南  |  Java後端工程師  |  熟悉Spring Boot | APP 開發設計經驗 |  3-5年以上相關經歷  (KTS_1332)',
#     'custNameRaw': '藝珂人事顧問股份有限公司',
#     'lon': '121.5198716',
#     'lat': '25.0421407',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12519723',
#     'jobName': '【北】(Golang)Backend Engineer｜後端工程師',
#     'jobNameSnippet': "【北】(Golang)Backend Engineer｜後端<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '',
#     'description': '【關於我們】 \n與全球十大平台網站合作，在交易、安全和區塊鏈產品創新方面提供一流的服務體驗。\n\n我們的產品研發團隊自成立以來一直秉承用戶至上和安全至上的理念，產品不斷更新迭代，技術穩中求新。加入產研團隊，你將和一群業內頂尖的技術夥伴一起，打磨高性能、高可靠、創新不斷的全球top5的平台，在這裡，你的發展空間無限，未來可期。\n\n我們正在全球招募更多優秀的志同道合的朋友加入我們，我們理想的候選人：積極主動，邏輯能力較好，有著良好的團隊合作和溝通協調能力；具有一定專研精神，敢於挑戰自我，勇於解決各種未知問題。\n\n【工作內容】\n1、獨立完成系統模組的開發，包括數據處理和商業邏輯處理。\n2、解決系統開發過程中的技術問題。\n3、參與 API 設計開發，以及相關支援功能的開發。\n\n【具備條件】\n1、1年以上工作經驗，電機、資工或相關專業大學及以上學歷。\n2、熟練掌握golang，熟悉 Linux 操作系統，熟練使用常見命令列工具。\n3、有扎實的網路應用程式基礎，對Socket通訊、UDP/TCP和HTTP協議及開發有深⼊理解，對 Nginx、OpenResty 等有一定瞭解和使用經驗。\n4、瞭解Linux相關知識，對 Docker, Kubernetes 等有實際操作使用經驗優先。\n5、熟悉 Python, Java，Shell 描述性語言、Lua 描述性語言等更佳。\n',
#     'optionEdu': '大學',
#     'period': '02',
#     'periodDesc': '1年',
#     'applyCnt': '00000',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000177876',
#     'custName': '大門科技顧問有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '1100000',
#     'salaryHigh': '9999999',
#     'salaryDesc': '年薪1,100,000元以上',
#     's10': '60',
#     'appearDate': '20220921',
#     'appearDateDesc': '9/21',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
# ...
#     'lat': '25.0421407',
#     'remoteWorkType': 1,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '9647852',
#     'jobName': 'Android應用軟體設計師',
#     'jobNameSnippet': "Android應用<em class='b-txt--highlight'>軟體</em>設計師",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '重慶南路二段51號13樓',
#     'description': '你不必是資訊本科系的人。\n\n只要對於異質系統整合和[[[軟體]]]開發工作有熱情，對於找出錯誤有智慧和耐心，對於自己寫作的[[[軟體]]]讓每天有上萬人次使用且穩定運作有自信，對於讓全台灣每天超過60%信用卡交易通過自己的系統處理有野心；\n\n歡迎您加入台灣信用卡刷卡機業',
#     'optionEdu': '大學',
#     'period': '03',
#     'periodDesc': '2年',
#     'applyCnt': '00002',
#     'applyDesc': '0~5人應徵',
#     'custNo': '70560595000',
#     'custName': '嘉利科技股份有限公司',
#     'coIndustry': '1001001001',
#     'coIndustryDesc': '電腦系統整合服務業',
#     'salaryLow': '0000000',
#     'salaryHigh': '0000000',
#     'salaryDesc': '待遇面議',
#     's10': '10',
#     'appearDate': '20220921',
#     'appearDateDesc': '9/21',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "你不必是資訊本科系的人。\n\n只要對於異質系統整合和<em class='b-txt--highlight'>軟體</em>開發工作有熱情，對於找出錯誤有智慧和耐心，對於自己寫作的<em class='b-txt--highlight'>軟體</em>讓每天有上萬人次使用且穩定運作有自信，對於讓全台灣每天超過60%信用卡交易通過自己的系統處理有野心；\n\n歡迎您加入台灣信用卡刷卡機業",
#     'tags': ['員工150人'],
#     'landmark': '距捷運中正紀念堂站380公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/5qsbw?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/5qsbw?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/wexyfjs?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'Android應用軟體設計師',
#     'custNameRaw': '嘉利科技股份有限公司',
#     'lon': '121.5148949',
#     'lat': '25.03119',
#     'remoteWorkType': 0,
#     'major': ['數學及電算機科學學科類', '資訊管理相關', '電機電子工程相關']},
#    {'jobType': '0',
#     'jobNo': '11604574',
#     'jobName': '車聯網平台 - 前端工程師 Frontend Engineer.',
#     'jobNameSnippet': "車聯網平台 - 前端<em class='b-txt--highlight'>工程師</em> Frontend Engineer.",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '思源街18號台大育成中心A棟206室',
#     'description': '及後端[[[工程師]]]密切合作\n3. 負責[[[軟體]]]之分析、設計以及程式撰寫。\n4. 規劃執行[[[軟體]]]架構及模組之設計，並控管[[[軟體]]]設計進度。\n5. 進行[[[軟體]]]之測試與修改。\n6. 規劃、執行與維護量產的產品。\n7. 協助研發[[[軟體]]]新技術與新工具。\n\n*/\n\n｜工作氛圍｜~',
#     'optionEdu': '大學',
#     'period': '00',
#     'periodDesc': '不拘',
#     'applyCnt': '00002',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000107281',
#     'custName': '三維人股份有限公司',
#     'coIndustry': '1001001003',
#     'coIndustryDesc': '網際網路相關業',
#     'salaryLow': '0630000',
#     'salaryHigh': '0770000',
#     'salaryDesc': '年薪630,000~770,000元',
#     's10': '60',
#     'appearDate': '20220922',
#     'appearDateDesc': '9/22',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "及後端<em class='b-txt--highlight'>工程師</em>密切合作\n3. 負責<em class='b-txt--highlight'>軟體</em>之分析、設計以及程式撰寫。\n4. 規劃執行<em class='b-txt--highlight'>軟體</em>架構及模組之設計，並控管<em class='b-txt--highlight'>軟體</em>設計進度。\n5. 進行<em class='b-txt--highlight'>軟體</em>之測試與修改。\n6. 規劃、執行與維護量產的產品。\n7. 協助研發<em class='b-txt--highlight'>軟體</em>新技術與新工具。\n\n*/\n\n｜工作氛圍｜~",
#     'tags': ['員工20人', '遠端工作'],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6wq5a?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/6wq5a?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bka35?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '車聯網平台 - 前端工程師 Frontend Engineer.',
#     'custNameRaw': '三維人股份有限公司',
#     'lon': '121.5292664',
#     'lat': '25.013113',
#     'remoteWorkType': 2,
#     'major': ['資訊工程相關', '其他數學及電算機科學相關']},
#    {'jobType': '0',
#     'jobNo': '12373535',
#     'jobName': 'Cocos 前端工程師、組長',
#     'jobNameSnippet': "Cocos 前端<em class='b-txt--highlight'>工程師</em>、組長",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '南昌路2段103號4樓之1',
#     'description': '工作內容：\n1. 負責 Cocos Creator 遊戲內容開發\n2. 負責 Cocos Creator 遊戲的性能分析、優化及維護\n3. 負責 Cocos Creator 實現與伺服器端交互功能 \n4. 與企劃及美術團隊溝通合作，分析策劃需求並完成遊戲功能的程式設計和實現\n\n條件特質：\n1. 1 年以上 Cocos Creator  開發遊戲經驗\n2. 熟悉 Websocket、HTTP等網路協定為佳\n3. 具備 TypeScript、HTML5 開發經驗\n4. 有完整專案參與經驗者佳\n5. 具備團隊溝通、獨立分析問題並解決之能力\n',
#     'optionEdu': '專科',
#     'period': '00',
#     'periodDesc': '不拘',
#     'applyCnt': '00001',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000174341',
#     'custName': '遊戲雲端科技股份有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0045000',
#     'salaryHigh': '9999999',
#     'salaryDesc': '月薪45,000元以上',
#     's10': '50',
#     'appearDate': '20220925',
#     'appearDateDesc': '9/25',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': '工作內容：\n1. 負責 Cocos Creator 遊戲內容開發\n2. 負責 Cocos Creator 遊戲的性能分析、優化及維護\n3. 負責 Cocos Creator 實現與伺服器端交互功能 \n4. 與企劃及美術團隊溝通合作，分析策劃需求並完成遊戲功能的程式設計和實現\n\n條件特質：\n1. 1 年以上 Cocos Creator  開發遊戲經驗\n2. 熟悉 Websocket、HTTP等網路協定為佳\n3. 具備 TypeScript、HTML5 開發經驗\n4. 有完整專案參與經驗者佳\n5. 具備團隊溝通、獨立分析問題並解決之能力\n',
#     'tags': ['員工22人'],
#     'landmark': '距捷運古亭站140公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7d7hb?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7d7hb?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6blptx?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'Cocos 前端工程師、組長',
#     'custNameRaw': '遊戲雲端科技股份有限公司',
#     'lon': '121.5214732',
#     'lat': '25.0267187',
#     'remoteWorkType': 0,
#     'major': ['資訊工程相關', '其他數學及電算機科學相關', '應用數學相關']},
#    {'jobType': '0',
#     'jobNo': '11813480',
#     'jobName': '車聯網平台 - 後端工程師 Backend Engineer',
#     'jobNameSnippet': "車聯網平台 - 後端<em class='b-txt--highlight'>工程師</em> Backend Engineer",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '思源街18號台大育成中心A棟206室',
#     'description': '後端[[[工程師]]]密切合作\n3. 負責[[[軟體]]]之分析、設計以及程式撰寫。\n4. 規劃執行[[[軟體]]]架構及模組之設計，並控管[[[軟體]]]設計進度。\n5. 進行[[[軟體]]]之測試與修改。\n6. 規劃、執行與維護量產的產品。\n7. 協助研發[[[軟體]]]新技術與新工具。\n\n*/\n\n｜工作氛圍｜\n我',
#     'optionEdu': '大學',
#     'period': '00',
#     'periodDesc': '不拘',
#     'applyCnt': '00001',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000107281',
#     'custName': '三維人股份有限公司',
#     'coIndustry': '1001001003',
#     'coIndustryDesc': '網際網路相關業',
#     'salaryLow': '0672000',
#     'salaryHigh': '0812000',
#     'salaryDesc': '年薪672,000~812,000元',
#     's10': '60',
#     'appearDate': '20220922',
#     'appearDateDesc': '9/22',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "後端<em class='b-txt--highlight'>工程師</em>密切合作\n3. 負責<em class='b-txt--highlight'>軟體</em>之分析、設計以及程式撰寫。\n4. 規劃執行<em class='b-txt--highlight'>軟體</em>架構及模組之設計，並控管<em class='b-txt--highlight'>軟體</em>設計進度。\n5. 進行<em class='b-txt--highlight'>軟體</em>之測試與修改。\n6. 規劃、執行與維護量產的產品。\n7. 協助研發<em class='b-txt--highlight'>軟體</em>新技術與新工具。\n\n*/\n\n｜工作氛圍｜\n我",
#     'tags': ['員工20人', '遠端工作'],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/717c8?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/717c8?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6bka35?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '車聯網平台 - 後端工程師 Backend Engineer',
#     'custNameRaw': '三維人股份有限公司',
#     'lon': '121.5292664',
#     'lat': '25.013113',
#     'remoteWorkType': 2,
#     'major': ['資訊工程相關']},
#    {'jobType': '0',
#     'jobNo': '12894630',
#     'jobName': '軟體助理工程師',
#     'jobNameSnippet': "<em class='b-txt--highlight'>軟體</em>助理<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '忠孝西路一段66號28樓',
#     'description': '1.[[[軟體]]]協同表單開發撰寫。\n2.需有 C# 及 MS SQL 基礎。\n3.本職缺可能依客戶資訊安全需求，需至客戶處或表單廠商處進行開發(均在台北、新北)。\n',
#     'optionEdu': '不拘',
#     'period': '00',
#     'periodDesc': '不拘',
#     'applyCnt': '00004',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000014811',
#     'custName': '科技管理家網路事業股份有限公司',
#     'coIndustry': '1001001003',
#     'coIndustryDesc': '網際網路相關業',
#     'salaryLow': '0032000',
#     'salaryHigh': '0035000',
#     'salaryDesc': '月薪32,000~35,000元',
#     's10': '50',
#     'appearDate': '20220924',
#     'appearDateDesc': '9/24',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "1.<em class='b-txt--highlight'>軟體</em>協同表單開發撰寫。\n2.需有 C# 及 MS SQL 基礎。\n3.本職缺可能依客戶資訊安全需求，需至客戶處或表單廠商處進行開發(均在台北、新北)。\n",
#     'tags': [],
#     'landmark': '距捷運台北車站260公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7odk6?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/7odk6?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6biaqj?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '軟體助理工程師',
#     'custNameRaw': '科技管理家網路事業股份有限公司',
#     'lon': '121.5153037',
#     'lat': '25.0460946',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12063993',
#     'jobName': 'ASP.NET WEB工程師',
#     'jobNameSnippet': "ASP.NET WEB<em class='b-txt--highlight'>工程師</em>",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '南昌路二段222號12樓之一',
#     'description': '1.負責項目基礎框架設計及構建。\n2.負責公司後端項目開發和規劃,進行需求分析和功能設計。\n3.對於[[[軟體]]]開發及新技術學習有濃厚興趣,以及較強的邏輯分析和獨立解決問題能力。\n必備條件:後端開發能力\n4. 後端下列程式開發合計3年以上開發經驗為必須：',
#     'optionEdu': '專科',
#     'period': '04',
#     'periodDesc': '3年',
#     'applyCnt': '00002',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000015919',
#     'custName': '嘉瑪科技股份有限公司',
#     'coIndustry': '1001003003',
#     'coIndustryDesc': '消費性電子產品製造業',
#     'salaryLow': '0050000',
#     'salaryHigh': '9999999',
#     'salaryDesc': '月薪50,000元以上',
#     's10': '50',
#     'appearDate': '20220919',
#     'appearDateDesc': '9/19',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "1.負責項目基礎框架設計及構建。\n2.負責公司後端項目開發和規劃,進行需求分析和功能設計。\n3.對於<em class='b-txt--highlight'>軟體</em>開發及新技術學習有濃厚興趣,以及較強的邏輯分析和獨立解決問題能力。\n必備條件:後端開發能力\n4. 後端下列程式開發合計3年以上開發經驗為必須：",
#     'tags': ['員工20人'],
#     'landmark': '距捷運古亭站350公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/76kmx?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/76kmx?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6biblb?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'ASP.NET WEB工程師',
#     'custNameRaw': '嘉瑪科技股份有限公司',
#     'lon': '121.5244899',
#     'lat': '25.0238245',
#     'remoteWorkType': 0,
#     'major': ['資訊工程相關', '資訊管理相關', '其他數學及電算機科學相關']},
#    {'jobType': '0',
#     'jobNo': '12040227',
#     'jobName': '軟體工程主管',
#     'jobNameSnippet': "<em class='b-txt--highlight'>軟體工程</em>主管",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '南昌路二段222號12樓之1',
#     'description': '1.負責項目基礎框架設計及構建。\n2.負責公司前後端項目開發和規劃,進行需求分析和功能設計。\n3.對於[[[軟體]]]開發及新技術學習有濃厚興趣,以及較強的邏輯分析和獨立解決問題能力。\n必備條件:全端開發能力\n後端下列程式開發任一項目3年以上開發經驗為必須：',
#     'optionEdu': '大學',
#     'period': '06',
#     'periodDesc': '5年',
#     'applyCnt': '00003',
#     'applyDesc': '0~5人應徵',
#     'custNo': '130000000015919',
#     'custName': '嘉瑪科技股份有限公司',
#     'coIndustry': '1001003003',
#     'coIndustryDesc': '消費性電子產品製造業',
#     'salaryLow': '0070000',
#     'salaryHigh': '9999999',
#     'salaryDesc': '月薪70,000元以上',
#     's10': '50',
#     'appearDate': '20220919',
#     'appearDateDesc': '9/19',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "1.負責項目基礎框架設計及構建。\n2.負責公司前後端項目開發和規劃,進行需求分析和功能設計。\n3.對於<em class='b-txt--highlight'>軟體</em>開發及新技術學習有濃厚興趣,以及較強的邏輯分析和獨立解決問題能力。\n必備條件:全端開發能力\n後端下列程式開發任一項目3年以上開發經驗為必須：",
#     'tags': ['員工20人'],
#     'landmark': '距捷運古亭站350公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/762ar?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/762ar?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/1a2x6biblb?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '軟體工程主管',
#     'custNameRaw': '嘉瑪科技股份有限公司',
#     'lon': '121.524522',
#     'lat': '25.023837',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '12056098',
#     'jobName': '(金融證券業)C# 開發工程師【維運部】',
#     'jobNameSnippet': "(金融證券業)C# 開發<em class='b-txt--highlight'>工程師</em>【維運部】",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '',
#     'description': '★ 負責C#.NET開發經驗，熟系MSSQL語法\n★有Window form 或開發看盤[[[軟體]]]相關經驗\n★有GIT版控相關經驗\n★有Trace Code相關經驗\n★ 需求分析、[[[軟體]]]規格、設計等技術文件的編寫工作。\n★ 具備良好工作態度及操守，工作積',
#     'optionEdu': '高中',
#     'period': '03',
#     'periodDesc': '2年',
#     'applyCnt': '00003',
#     'applyDesc': '0~5人應徵',
#     'custNo': '70584647000',
#     'custName': '普鴻資訊股份有限公司',
#     'coIndustry': '1001001002',
#     'coIndustryDesc': '電腦軟體服務業',
#     'salaryLow': '0000000',
#     'salaryHigh': '0000000',
#     'salaryDesc': '待遇面議',
#     's10': '10',
#     'appearDate': '20220922',
#     'appearDateDesc': '9/22',
#     'optionZone': '0',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "★ 負責C#.NET開發經驗，熟系MSSQL語法\n★有Window form 或開發看盤<em class='b-txt--highlight'>軟體</em>相關經驗\n★有GIT版控相關經驗\n★有Trace Code相關經驗\n★ 需求分析、<em class='b-txt--highlight'>軟體</em>規格、設計等技術文件的編寫工作。\n★ 具備良好工作態度及操守，工作積",
#     'tags': ['員工170人'],
#     'landmark': '',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/76ejm?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/76ejm?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/wfc9y6w?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': '(金融證券業)C# 開發工程師【維運部】',
#     'custNameRaw': '普鴻資訊股份有限公司',
#     'lon': '121.5198716',
#     'lat': '25.0421407',
#     'remoteWorkType': 0,
#     'major': []},
#    {'jobType': '0',
#     'jobNo': '4289933',
#     'jobName': 'PHP 軟體程式開發人員',
#     'jobNameSnippet': "PHP <em class='b-txt--highlight'>軟體</em>程式開發人員",
#     'jobRole': '1',
#     'jobRo': '1',
#     'jobAddrNo': '6001001001',
#     'jobAddrNoDesc': '台北市中正區',
#     'jobAddress': '忠孝東路一段150號5樓',
#     'description': '經驗\n• Linux 主機管理與設定經驗\n• JavaScript： 例如 jQuery 使用經驗\n• 配合度高且主動性佳者優先考量\n\n【提供環境】\n• [[[工程師]]]皆配備專屬筆電 (MacBook Pro)\n• 公司有提供職前訓練及定期技術分享\n• 舒',
#     'optionEdu': '專科',
#     'period': '00',
#     'periodDesc': '不拘',
#     'applyCnt': '00001',
#     'applyDesc': '0~5人應徵',
#     'custNo': '27520341000',
#     'custName': '百加資通股份有限公司',
#     'coIndustry': '1001001001',
#     'coIndustryDesc': '電腦系統整合服務業',
#     'salaryLow': '0035000',
#     'salaryHigh': '0040000',
#     'salaryDesc': '月薪35,000~40,000元',
#     's10': '50',
#     'appearDate': '20220920',
#     'appearDateDesc': '9/20',
#     'optionZone': '2560',
#     'isApply': '0',
#     'applyDate': '',
#     'isSave': '0',
#     'descSnippet': "經驗\n• Linux 主機管理與設定經驗\n• JavaScript： 例如 jQuery 使用經驗\n• 配合度高且主動性佳者優先考量\n\n【提供環境】\n• <em class='b-txt--highlight'>工程師</em>皆配備專屬筆電 (MacBook Pro)\n• 公司有提供職前訓練及定期技術分享\n• 舒",
#     'tags': [],
#     'landmark': '距捷運善導寺站260公尺',
#     'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/2jy4t?channel=104rpt&jobsource=apply_analyze',
#      'job': '//www.104.com.tw/job/2jy4t?jobsource=jolist_a_relevance',
#      'cust': '//www.104.com.tw/company/cn4wf0o?jobsource=jolist_a_relevance'},
#     'jobsource': 'jolist_a_relevance',
#     'jobNameRaw': 'PHP 軟體程式開發人員',
#     'custNameRaw': '百加資通股份有限公司',
#     'lon': '121.525764',
#     'lat': '25.044014',
#     'remoteWorkType': 0,
#     'major': ['資訊管理相關', '資訊工程相關', '其他數學及電算機科學相關']}],
#   'count': ['497', '486', '11', '0', '0', '0', '0'],
#   'pageNo': 2,
#   'totalPage': 17,
#   'totalCount': 486},
#  'statusMsg': '成功',
#  'errorMsg': ''}
